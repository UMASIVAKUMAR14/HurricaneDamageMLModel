# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"] = (8,3)

# %%
img = cv2.imread('./archive/test/damage/-93.548123_30.900623.jpeg')
img.shape
# Out:
# (128, 128, 3)

# %%
plt.imshow(img)

# %%
grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
grey.shape
# Out:
# (128, 128)

# %%
grey
# Out:
# array([[33, 32, 31, ..., 60, 59, 72],
#        [39, 37, 35, ..., 60, 57, 57],
#        [40, 35, 32, ..., 64, 59, 48],
#        ...,
#        [50, 52, 54, ..., 98, 85, 71],
#        [57, 53, 50, ..., 92, 79, 65],
#        [66, 56, 46, ..., 76, 76, 78]], dtype=uint8)
